# %% [markdown]
# ### Total individuals in each sanctions-YYYYMMDD-persons.ftm.json (2021-2026)

# %% [markdown]
# ### Total individuals with 'sanction' topics in each sanctions-YYYYMMDD-persons.ftm.json (2021-2026); Total individuals with 'sanction_counter' topics in each sanctions-YYYYMMDD-persons.ftm.json (2021-2026); Total individuals with 'sanction' and 'sanction_counter' topics in each sanctions-YYYYMMDD-persons.ftm.json (2021-2026)

# %% [markdown]
# ### Total individuals WITH and WITHOUT gender with 'sanction' topics in each sanctions-YYYYMMDD-persons.ftm.json (2021-2026); Total individuals WITH and WITHOUT gender with 'sanction_counter' topics in each sanctions-YYYYMMDD-persons.ftm.json (2021-2026); Total individuals WITH and WITHOUT gender with 'sanction' and 'sanction_counter' topics in each sanctions-YYYYMMDD-persons.ftm.json (2021-2026)

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ### TOTAL individuals in statements_persons_2026.csv (2026)

# %% [markdown]
# ### TOTAL individuals with 'sanction' topics in statements_persons_2026.csv (2026); TOTAL individuals with 'sanction_counter' topics in statements_persons_2026.csv (2026); TOTAL individuals with 'sanction' and 'sanction_counter' topics statements_persons_2026.csv (2026)

# %% [markdown]
# ### ### TOTAL individuals WITH and WITHOUT gender with 'sanction' topics in statements_persons_2026.csv (2026); TOTAL individuals WITH and WITHOUT gender with 'sanction_counter' topics in statements_persons_2026.csv (2026); TOTAL individuals WITH and WITHOUT gender with 'sanction' and 'sanction_counter' topics statements_persons_2026.csv (2026)
