# %% [markdown]
# # COUNT OF PERSONS (schema:'Person'), TOPICS (prop:'topics' - value:'sanction', prop:'topics' - value:'sanction.counter'), GENDER (prop:'gender' - value:'male','female','other')

# %% [markdown]
# ## JSONs processing outcomes

# %% [markdown]
# ### Total individuals for each sanctions-YYYYMMDD-persons.ftm.json (2021-2026).

# %%
from opensanctions.raw_data_freqs import json_total_individual_per_year

json_total_individual_per_year()
# Out:
#       unique_individuals
# year
# 2021               14250
# 2022               16619
# 2023               22168
# 2024               26233
# 2025               40730
# 2026               40877

# %% [markdown]
# ### Total individuals with topics equal 'sanction' OR 'sanction.counter' for each sanctions-YYYYMMDD-persons.ftm.json (2021-2026).

# %%
from opensanctions.raw_data_freqs import json_total_sanctioned_individual

json_total_sanctioned_individual()
# Out:
#       sanctioned_individuals
# year
# 2021                   10203
# 2022                   16175
# 2023                   21100
# 2024                   24895
# 2025                   35092
# 2026                   35241

# %% [markdown]
# ### Total individuals with topics equal 'sanction.counter' and not equal 'sanction' for each sanctions-YYYYMMDD-persons.ftm.json (2021-2026).

# %%
from opensanctions.raw_data_freqs import json_total_sanction_counter_and_not_sanction_individual_per_year

json_total_sanction_counter_and_not_sanction_individual_per_year()
# Out:
#       sanction_counter_individuals
# year
# 2021                             0
# 2022                             0
# 2023                             0
# 2024                          1843
# 2025                          3936
# 2026                          3965

# %% [markdown]
# ### Total individuals with gender, topics equal 'sanction' OR 'sanction.counter' for each sanctions-YYYYMMDD-persons.ftm.json (2021-2026).
# abs freq = sanctioned individuals

# %%
from opensanctions.raw_data_freqs import json_total_sanctioned_individual_with_gender_per_year

json_total_sanctioned_individual_with_gender_per_year()
# Out:
#       sanctioned_individuals  relative_frequency
# year
# 2021                    3289               32.24
# 2022                    5187               32.07
# 2023                    6422               30.44
# 2024                    7794               31.31
# 2025                    8618               24.56
# 2026                    8693               24.67

# %% [markdown]
# ### Total individuals without gender, topics equal 'sanction' OR 'sanction.counter' for each sanctions-YYYYMMDD-persons.ftm.json (2021-2026).

# %%
from opensanctions.raw_data_freqs import json_total_sanctioned_individual_without_gender_per_year

    
json_total_sanctioned_individual_without_gender_per_year()
# Out:
#       sanctioned_individuals
# year
# 2021                    6914
# 2022                   10988
# 2023                   14678
# 2024                   17101
# 2025                   26474
# 2026                   26548

# %% [markdown]
# ### Total individuals with gender, topics equal 'sanction.counter' and not equal 'sanction' for each sanctions-YYYYMMDD-persons.ftm.json (2021-2026).
# abs freq = sanctioned individuals

# %% [markdown]
# ### Total individuals without gender, topics equal 'sanction.counter' and not equal 'sanction' for each sanctions-YYYYMMDD-persons.ftm.json (2021-2026).

# %% [markdown]
# ## CSV processing outcomes

# %% [markdown]
# ### Total individuals for statements_persons_2026.csv (2026).

# %% [markdown]
# ### Total individuals with topics equal 'sanction' OR 'sanction_.ounter' for statements_persons_2026.csv (2026).

# %% [markdown]
# ### Total individuals with topics equal 'sanction.counter' and not equal 'sanction' for statements_persons_2026.csv (2026).

# %% [markdown]
# ### Total individuals with gender, topics equal 'sanction' OR 'sanction.counter' for statements_persons_2026.csv (2026).
# abs freq = sanctioned individuals

# %% [markdown]
# ### Total individuals without gender, topics equal 'sanction' OR 'sanction.counter' for statements_persons_2026.csv (2026).

# %% [markdown]
# ### Total individuals with gender, topics equal 'sanction.counter' and not equal 'sanction' for statements_persons_2026.csv (2026).
# abs freq = sanctioned individuals

# %% [markdown]
# ### Total individuals without gender, topics equal 'sanction.counter' and not equal 'sanction' for statements_persons_2026.csv (2026).

# %% [markdown]
# ###

# %% [markdown]
# # COUNT OF PERSONS, TOPICS, GENDER, DATASETS (dataset:'...')

# %% [markdown]
# ### TOTAL individuals WITH and WITHOUT valid dataset for gender information for statements_persons_2026.csv (2026)

# %% [markdown]
# ### TOTAL recurrences of gender information for each valid dataset for statements_persons_2026.csv (2026)

# %% [markdown]
# ### TOTAl individuals for each gender type (female, male, other/whatever word) and TOTAL of individuals with more than one gender type (print these cases) for statements_persons_2026.csv (2026)

# %% [markdown]
# ### Retrieve info on senders from dataset. For each sender, count total of occurrences of gender information in statements_persons_2026.csv (2026)

# %% [markdown]
# ### Frequency of ethnicity, religion .... for each gendeer type
