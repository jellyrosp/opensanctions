# %% [markdown]
# # COUNT OF PERSONS (schema:'Person'), TOPICS (prop:'topics' - value:'sanction', prop:'topics' - value:'sanction_counter'), GENDER (prop:'gender' - value:'male','female','other')

# %% [markdown]
# ### Total individuals for each sanctions-YYYYMMDD-persons.ftm.json (2021-2026)

# %% [markdown]
# ### Total individuals with 'sanction' topics for each sanctions-YYYYMMDD-persons.ftm.json (2021-2026); Total individuals with 'sanction_counter' topics for each sanctions-YYYYMMDD-persons.ftm.json (2021-2026); Total individuals with 'sanction' and 'sanction_counter' topics in each sanctions-YYYYMMDD-persons.ftm.json (2021-2026)

# %% [markdown]
# ### Total individuals WITH and WITHOUT gender with 'sanction' topics ONLY in each sanctions-YYYYMMDD-persons.ftm.json (2021-2026); Total individuals WITH and WITHOUT gender with 'sanction_counter' topics ONLY in each sanctions-YYYYMMDD-persons.ftm.json (2021-2026); Total individuals WITH and WITHOUT gender with 'sanction' and 'sanction_counter' topics in each sanctions-YYYYMMDD-persons.ftm.json (2021-2026)

# %% [markdown]
# ###

# %% [markdown]
# ### TOTAL individuals in statements_persons_2026.csv (2026)

# %% [markdown]
# ### TOTAL individuals with 'sanction' topics ONLY in statements_persons_2026.csv (2026); TOTAL individuals with 'sanction_counter' topics ONLY in statements_persons_2026.csv (2026); TOTAL individuals with 'sanction' and 'sanction_counter' topics statements_persons_2026.csv (2026)

# %% [markdown]
# ### TOTAL individuals WITH and WITHOUT gender with 'sanction' topics ONLY in statements_persons_2026.csv (2026); TOTAL individuals WITH and WITHOUT gender with 'sanction_counter' topics ONLY in statements_persons_2026.csv (2026); TOTAL individuals WITH and WITHOUT gender with 'sanction' and 'sanction_counter' topics statements_persons_2026.csv (2026)

# %% [markdown]
# ###

# %% [markdown]
# # COUNT OF PERSONS, TOPICS, GENDER, DATASETS (dataset:'...')

# %% [markdown]
# ### TOTAL individuals WITH and WITHOUT valid dataset for gender information in statements_persons_2026.csv (2026)

# %% [markdown]
# ### TOTAL recurrences of gender information for each valid dataset in statements_persons_2026.csv (2026)

# %% [markdown]
# ### TOTAl individuals for each gender (female, male, other/whatever word) and TOTAL of individuals with more than one gender (print these cases) in statements_persons_2026.csv (2026)

# %% [markdown]
# ### Retrieve info on senders from dataset. For each sender, count total of occurrences of gender information in statements_persons_2026.csv (2026)

# %% [markdown]
# ### Frequency of ethnicity, religion .... for each gendeer type
