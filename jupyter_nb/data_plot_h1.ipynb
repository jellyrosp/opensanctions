# %%
import sys
from pathlib import Path

# Add the root directory of your project to the Python path
project_root = Path("/home/ljutach/Documents/auri_projects/opensanctions")
sys.path.append(str(project_root))

# Import the functions
from src.opensanctions.h1_gender_sources import gender_source_frequency
from src.opensanctions.persons import persons_extract
from src.opensanctions.download import download_dataset_file

# %%
# Example: Call the gender_source_frequency function
input_file = project_root /"datasets/2026/statements_2026.csv"
frequency_table = gender_source_frequency(input_file)
print(frequency_table)
