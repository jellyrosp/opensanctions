# %% [markdown]
# # JSON processing outcomes

# %% [markdown]
# ### Frequency of nationality information by gender category.

# %%
from opensanctions.const import country_mapping
from IPython.display import display
from opensanctions.h2.h2_json import json_categorical_frequency_for_sanctioned_gender_by_year

results =json_categorical_frequency_for_sanctioned_gender_by_year(category='nationality', mapping_dict=country_mapping, min_count=50)

# Access results for a specific year
for year, relative_frequency_table in results.items():
    print(f"Results for {year}:")
    display(relative_frequency_table)
# Out:
# Results for 2021:
# gender            female   male
# nationality_name
# Belarus            16.23  83.77
# China              14.47  85.53
# Iran                2.39  97.61
# Iraq               21.31  78.69
# Mexico             20.37  79.63
# Myanmar            22.09  77.91
# North Korea         2.83  97.17
# Russia              8.23  91.77
# Syria               7.14  92.86
# Tunisia            24.56  75.44
# Ukraine            15.84  84.16
# Venezuela          17.65  82.35
# Results for 2022:
# gender            female   male
# nationality_name
# Belarus            13.52  86.48
# China              14.67  85.33
# Iran                2.75  97.25
# Iraq               21.31  78.69
# Lebanon             2.86  97.14
# Mexico             19.01  80.99
# Myanmar            16.94  83.06
# Nicaragua          19.61  80.39
# North Korea         2.38  97.62
# Russia             16.44  83.56
# Syria               7.39  92.61
# Ukraine            14.71  85.29
# Venezuela          17.65  82.35
# ...

# %% [markdown]
# ### Distribution of gender by topics on sanctioned individuals.

# %%
from opensanctions.h2.h2_json import  gender_distribution_over_topics_by_year_json

gender_distribution_over_topics_by_year_json()
# Out:
#       male  female  mixed  Year           Topic  male_rel_freq(%)  \
# 0     82.0     2.0    0.0  2021    crime.terror             97.62
# 1    119.0     4.0    0.0  2022    crime.terror             96.75
# 2    121.0     4.0    0.0  2023    crime.terror             96.80
# 3    133.0     4.0    0.0  2024    crime.terror             97.08
# 4   2304.0   198.0    2.0  2025  export.control             92.01
# 5    144.0     4.0    0.0  2025    crime.terror             97.30
# 6      3.0     0.0    0.0  2025       debarment            100.00
# 7      2.0     0.0    0.0  2025          wanted            100.00
# 8      1.0     0.0    0.0  2025    asset.frozen            100.00
# 9   2315.0   200.0    2.0  2026  export.control             91.97
# 10   145.0     4.0    0.0  2026    crime.terror             97.32
# 11     3.0     0.0    0.0  2026       debarment            100.00
# 12     2.0     0.0    0.0  2026          wanted            100.00
# ...

# %% [markdown]
# ### Create csv file with extracted object properties:"notes" for each individual.
