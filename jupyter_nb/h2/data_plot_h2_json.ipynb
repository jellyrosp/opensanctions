# %% [markdown]
# # JSON processing outcomes

# %% [markdown]
# ### Frequency of nationality information by gender category.

# %%
from opensanctions.const import country_mapping
from IPython.display import display
from opensanctions.h2.h2_json import json_categorical_frequency_for_sanctioned_gender_by_year

results =json_categorical_frequency_for_sanctioned_gender_by_year(category='nationality', mapping_dict=country_mapping, min_count=50)

# Access results for a specific year
for year, relative_frequency_table in results.items():
    print(f"Results for {year}:")
    display(relative_frequency_table)
# Out:
# Results for 2021:
# gender            female    male
# nationality_name
# Afghanistan         0.00  100.00
# Algeria             0.00  100.00
# Angola             33.33   66.67
# Argentina           0.00  100.00
# Australia           0.00  100.00
# ...                  ...     ...
# United States       0.00  100.00
# Uzbekistan         33.33   66.67
# Venezuela          17.65   82.35
# Yemen               0.00  100.00
# Zimbabwe            0.00  100.00
#
# [97 rows x 2 columns]
# Results for 2022:
# gender            female    male
# nationality_name
# Afghanistan         0.00  100.00
# Albania             0.00  100.00
# Algeria             0.00  100.00
# Angola             33.33   66.67
# Argentina           0.00  100.00
# ...                  ...     ...
# United States       0.00  100.00
# Uzbekistan         66.67   33.33
# Venezuela          17.65   82.35
# Yemen               0.00  100.00
# Zimbabwe           11.11   88.89
#
# [116 rows x 2 columns]
# Results for 2023:
# gender            female    male
# nationality_name
# Afghanistan         0.00  100.00
# Albania             0.00  100.00
# Algeria             0.00  100.00
# Angola             33.33   66.67
# Argentina           0.00  100.00
# ...                  ...     ...
# United States       0.00  100.00
# Uzbekistan         50.00   50.00
# Venezuela          18.10   81.90
# Yemen               0.00  100.00
# Zimbabwe           10.00   90.00
#
# [122 rows x 2 columns]
# Results for 2024:
# gender            female    male
# nationality_name
# Afghanistan         0.00  100.00
# Albania             0.00  100.00
# Algeria             0.00  100.00
# Angola             50.00   50.00
# Argentina           0.00  100.00
# ...                  ...     ...
# United States       0.00  100.00
# Uzbekistan         33.33   66.67
# Venezuela          13.13   86.87
# Yemen               0.00  100.00
# Zimbabwe           23.08   76.92
#
# [129 rows x 2 columns]
# Results for 2025:
# gender            female    male
# nationality_name
# Afghanistan         0.00  100.00
# Albania            11.11   88.89
# Algeria             6.25   93.75
# Angola             50.00   50.00
# Argentina           0.00  100.00
# ...                  ...     ...
# United States       0.00  100.00
# Uzbekistan         23.08   76.92
# Venezuela          13.97   86.03
# Yemen               0.00  100.00
# Zimbabwe           25.00   75.00
#
# [133 rows x 2 columns]
# Results for 2026:
# gender            female    male
# nationality_name
# Afghanistan         0.00  100.00
# Albania            11.11   88.89
# Algeria             0.00  100.00
# Angola             50.00   50.00
# Argentina           0.00  100.00
# ...                  ...     ...
# Uzbekistan         27.78   72.22
# Vanuatu             0.00  100.00
# Venezuela          14.07   85.93
# Yemen               0.00  100.00
# Zimbabwe           25.00   75.00
#
# [139 rows x 2 columns]

# %% [markdown]
# ### Create csv file with extracted object properties:"notes" for each individual.

# %% [markdown]
# ### Create csv file with extracted object properties:"position" for each individual.

# %% [markdown]
# ### Frequency of topics not 'sanction' or 'sanction-counter' by gender category.
