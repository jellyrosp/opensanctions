# %% [markdown]
# # NESTED JSON processing outcomes

# %% [markdown]
# ### NOTE: Take id of individuals from either csv or json and search in this dataset.

# %% [markdown]
# ### Person and sanctioned and gender and other topics and schema:'Sanction' with properties: 'reason', 'startDate', 'endDate'
