# %% [markdown]
# # Hypothesis 2: JSON processing outcomes

# %% [markdown]
# Finally, although the following data is not directly relevant to confirming Hypothesis 2, it was analyzed to determine whether any significant trends exist. Unfortunately, the sample size of sanctioned individuals per nationality is insufficient to derive statistically significant or generalizable conclusions from the data. The following graphs illustrate a condensed representation of the nationality (Figure 2, Table 2) of sanctioned individuals, categorized by gender. The accompanying tables provide the complete dataset for each year. For graphical clarity, only values with a sufficient number of cases (count ≥ 50) are displayed. Therefore, the selected data highlights the most representative cases.

# %% [markdown]
# **Figure 2, Table 2**

# %%
from opensanctions.const import country_mapping
from IPython.display import display
from opensanctions.h2.h2_json import json_categorical_frequency_for_sanctioned_gender_by_year

results =json_categorical_frequency_for_sanctioned_gender_by_year(category='nationality', mapping_dict=country_mapping, min_count=50)

# Access results for a specific year
for year, relative_frequency_table in results.items():
    print(f"Results for {year}:")
    display(relative_frequency_table)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from opensanctions.const import country_mapping
#       2 from IPython.display import display
# ----> 3 from opensanctions.h2.h2_json import json_categorical_frequency_for_sanctioned_gender_by_year
#       5 results =json_categorical_frequency_for_sanctioned_gender_by_year(category='nationality', mapping_dict=country_mapping, min_count=50)
#       7 # Access results for a specific year
#
# File ~/Documents/auri_projects/opensanctions/src/opensanctions/h2/h2_json.py:2
#       1 import json
# ----> 2 import ollama
#       3 from pathlib import Path
#       4 import pandas as pd
#
# ModuleNotFoundError: No module named 'ollama'

# %% [markdown]
# ### Create csv file with extracted object properties:"notes" for each individual.

# %% [markdown]
# ### Create csv file with extracted object properties:"position" for each individual.

# %% [markdown]
# ### Frequency of topics not 'sanction' or 'sanction-counter' by gender category.
