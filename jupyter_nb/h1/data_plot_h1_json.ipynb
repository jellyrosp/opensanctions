# %% [markdown]
# # JSONs processing outcomes

# %% [markdown]
# ### Total individuals for each sanctions-YYYYMMDD-persons.ftm.json (2021-2026).

# %%
from opensanctions.h1.h1_json import json_total_individual_per_year

json_total_individual_per_year()
# Out:
#       unique_individuals
# year
# 2021               14250
# 2022               16619
# 2023               22168
# 2024               26233
# 2025               40730
# 2026               40877

# %% [markdown]
# ### Total individuals with topics equal 'sanction' OR 'sanction.counter' for each sanctions-YYYYMMDD-persons.ftm.json (2021-2026).

# %%
from opensanctions.h1.h1_json import json_total_sanctioned_individual

json_total_sanctioned_individual()
# Out:
#       sanctioned_individuals  relative_frequency(%)
# year
# 2021                   10203                  71.60
# 2022                   16175                  97.33
# 2023                   21100                  95.18
# 2024                   24895                  94.90
# 2025                   35092                  86.16
# 2026                   35241                  86.21

# %% [markdown]
# ### Total individuals with topics equal 'sanction.counter' and not equal 'sanction' for each sanctions-YYYYMMDD-persons.ftm.json (2021-2026).

# %%
from opensanctions.h1.h1_json import json_total_sanction_counter_and_not_sanction_individual_per_year

json_total_sanction_counter_and_not_sanction_individual_per_year()
# Out:
#       sanction_counter_individuals
# year
# 2021                             0
# 2022                             0
# 2023                             0
# 2024                          1843
# 2025                          3936
# 2026                          3965

# %% [markdown]
# ### Total individuals with gender, topics equal 'sanction' OR 'sanction.counter' for each sanctions-YYYYMMDD-persons.ftm.json (2021-2026).
# abs freq = sanctioned individuals

# %%
from opensanctions.h1.h1_json import json_total_sanctioned_individual_with_gender_per_year

json_total_sanctioned_individual_with_gender_per_year()
# Out:
#       sanctioned_individuals  relative_frequency(%)
# year
# 2021                    3289                  100.0
# 2022                    5187                  100.0
# 2023                    6422                  100.0
# 2024                    7794                  100.0
# 2025                    8618                  100.0
# 2026                    8693                  100.0

# %% [markdown]
# ### Distribution of gender categories for sanctioned individuals.
# python result: male 7596, female 1090, mixed 7

# %%
from opensanctions.h1.h1_json import count_gender_categories_for_sanctioned_individuals_json

count_gender_categories_for_sanctioned_individuals_json()
# Out:
#       male  male_rel_freq(%)  female  female_rel_freq(%)  mixed  \
# year
# 2021  3010             91.52     278                8.45      1
# 2022  4550             87.72     636               12.26      1
# 2023  5635             87.75     780               12.15      7
# 2024  6831             87.64     957               12.28      6
# 2025  7523             87.29    1088               12.62      7
# 2026  7596             87.38    1090               12.54      7
#
#       mixed_rel_freq(%)
# year
# 2021               0.03
# 2022               0.02
# 2023               0.11
# 2024               0.08
# 2025               0.08
# 2026               0.08

# %% [markdown]
# ### Total individuals without gender, topics equal 'sanction' OR 'sanction.counter' for each sanctions-YYYYMMDD-persons.ftm.json (2021-2026).

# %%
from opensanctions.h1.h1_json import json_total_sanctioned_individual_without_gender_per_year

    
json_total_sanctioned_individual_without_gender_per_year()
# Out:
#       sanctioned_individuals
# year
# 2021                    6914
# 2022                   10988
# 2023                   14678
# 2024                   17101
# 2025                   26474
# 2026                   26548

# %% [markdown]
# ### Total individuals with gender, topics equal 'sanction.counter' and not equal 'sanction' for each sanctions-YYYYMMDD-persons.ftm.json (2021-2026).
# abs freq = sanctioned individuals

# %%
from opensanctions.h1.h1_json import json_total_sanction_counter_and_not_sanction_individual_with_gender_per_year

json_total_sanction_counter_and_not_sanction_individual_with_gender_per_year()
# Out:
#       sanction_counter_individuals  relative_frequency(%)
# year
# 2021                             0                    0.0
# 2022                             0                    0.0
# 2023                             0                    0.0
# 2024                             0                    0.0
# 2025                             0                    0.0
# 2026                             0                    0.0

# %% [markdown]
# ### Total individuals without gender, topics equal 'sanction.counter' and not equal 'sanction' for each sanctions-YYYYMMDD-persons.ftm.json (2021-2026).

# %%
from opensanctions.h1.h1_json import json_total_sanction_counter_and_not_sanction_individual_without_gender_per_year

json_total_sanction_counter_and_not_sanction_individual_without_gender_per_year()
# Out:
#       sanction_counter_individuals
# year
# 2021                             0
# 2022                             0
# 2023                             0
# 2024                          1843
# 2025                          3936
# 2026                          3965

# %% [markdown]
# ###
